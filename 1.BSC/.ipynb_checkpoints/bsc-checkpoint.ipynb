# %%
from pydoc import pager
import requests
import json
import time
import pandas as pd
import numpy as np
from tqdm import tqdm
key = "7ZCNGGDTJKSQT2ID4RKBTGAMM9MKEBJXYE"
# addr = "0x780645b0e4e2c2948b4cb99cc5a51dedd00ac931"

class Bsc:
    def __init__(self,addr):
        self.addr = addr
        self.page = 1
        self.size = 100
        self.action = "txlist"

    def start(self):
        pass

    def get_txlist(self):
        print("开始爬取账户交易信息")
        tx_lst = []
        while True:
            params = {
                "action":self.action,
                "address":self.addr,
                "page":self.page,
                "size":self.size
                }
            url = f"https://api.bscscan.com/api?module=account"
            try:
                r = requests.get(url,params=params)
            except Exception as e:
                time.sleep(1)
                continue

            if (r.status_code == 200) and (len(r.json()['data']['items'])>0):
                for i in r.json()['data']['items']:
                    try:
                        if (i['successful'] == True) and (0 < len(i['log_events']) <= 2) and (i["to_address_label"]==None):
                            date = i['block_signed_at'].replace('T',' ').replace('Z','') #交易日期
                            tx_hash = i['tx_hash'] #交易哈希
                    except Exception as e:
                        continue
                page_number+=1
                age = len(res['tx_hash'])
                if age//2500>0:
                    print(f"已爬取{age}条")
            elif (r.status_code == 200) and (len(r.json()['data']['items'])==0):
                print('爬取完毕')
                break
            elif r.status_code != 200: 
                time.sleep(3)
                continue

    def request(self,url,headers):
        try:
            r = requests.get(url,headers=headers)
        except Exception as e:
            print(e)
            print("捕获异常，等待 {} 秒后继续尝试请求！".format(3))
            time.sleep(3)

        return r.json()


if __name__ == "__main__":
    addr = "0x287eEDB0145c6A16194647CD6aFB11E0aB337076"
    Bsc(addr).start()

# %%
import requests
params = {
    'action':'txlist',
    'address':'0x287eEDB0145c6A16194647CD6aFB11E0aB337076',
    'key':'7ZCNGGDTJKSQT2ID4RKBTGAMM9MKEBJXYE',
    'page':1,
    'size':10
    }
url = f"https://api.bscscan.com/api?module=account"
r = requests.get(url,params=params)

# %%
r.json()
# Out:
# {'status': '1',
#  'message': 'OK-Missing/Invalid API Key, rate limit of 1/5sec applied',
#  'result': [{'blockNumber': '17355352',
#    'timeStamp': '1651197937',
#    'hash': '0x4445a7e5763855e9bad8b14cac8af568a15c73354a80c3df3d8898cfb6c43f26',
#    'nonce': '7',
#    'blockHash': '0x321116e330c3abefbc0517fa8c3d6211afc3b84de8cd988d946060db433a4870',
#    'transactionIndex': '123',
#    'from': '0x40d51a21661065c2016b75dceed17ff2cb0898e4',
#    'to': '',
#    'value': '0',
#    'gas': '1434899',
#    'gasPrice': '5000000000',
#    'isError': '0',
#    'txreceipt_status': '1',
#    'input': '...',
#    'contractAddress': '0x287eedb0145c6a16194647cd6afb11e0ab337076',
#    'cumulativeGasUsed': '25210488',
#    'gasUsed': '1434899',
#    'confirmations': '3214722',
#    'methodId': '0x60806040',
#    'functionName': 'atInversebrah(int248 a, uint48[] b, uint32 c, bytes20[] d, bytes30[] e)'},
#   {'blockNumber': '17355354',
#    'timeStamp': '1651197943',
# ...
